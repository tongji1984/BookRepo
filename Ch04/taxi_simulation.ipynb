# %%
import numpy as np
from IPython import embed

# %% [markdown]
# Example Code 121

# %%
def taxi_id_number(num_taxis):
    # generate integer from zero to len(num_taxis)-1
    arr = np.arange(num_taxis)
    # set number in arr randomly
    np.random.shuffle(arr)
    # generate arr[i] as a generator
    for i in range(num_taxis):
        yield arr[i]

# %% [markdown]
# Example Code 122

# %%
# ids = taxi_id_number(10)
# print(next(ids))
# print(next(ids))
# print(next(ids))

# %%
def shift_info():
    # freqs: the mean of trip number
    start_times_and_freqs = [(0,8), (8,30), (16, 15)]
    indices = np.arange(len(start_times_and_freqs))
    while True:
        idx = np.random.choice(indices, p=[0.25, 0.5, 0.25])
        start = start_times_and_freqs[idx]
        yield (start[0], start[0]+7.5, start[1])

# %% [markdown]
# Example Code 123

# %%
def taxi_process(taxi_id_generator, shift_info_generator):
    taxi_id = next(taxi_id_generator)
    shift_start, shift_end, shift_mean_trips = next(shift_info_generator)
    # generate random variable with shift_mean_trips and standard deviation
    actual_trips = round(np.random.normal(loc=shift_mean_trips, scale=2))
    # 6.5 is in use. 1.0 is vacacy.
    average_trip_time = 6.5/shift_mean_trips * 60
    between_events_time = 1.0/ (shift_mean_trips -1)* 60
    time = shift_start
    yield TimePoint(taxi_id, "start shift", time)
    deltaT = np.random.poisson(between_events_time)/60
    time += deltaT
    for i in range(actual_trips):
        yield TimePoint(taxi_id, "pick up", time)
        deltaT = np.random.poisson(average_trip_time)/60
        time += deltaT
        yield TimePoint(taxi_id, "drop off", time)
        deltaT = np.random.poisson(between_events_time)/60
        time += deltaT
    deltaT = np.random.poisson(between_events_time)/60
    time += deltaT
    yield TimePoint(taxi_id, "end_shift", time)

# %%
from dataclasses import dataclass
@dataclass
class TimePoint:
    taxi_id: int
    name: str
    time: float

    def __lt__(self, other):
        return self.time < other.time

# %% [markdown]
# Example Code 124-125

# %%
import queue

class Simulator:
    def __init__(self, num_taxis):
        self._time_points = queue.PriorityQueue()
        taxi_id_generator = taxi_id_number(num_taxis)
        shift_info_generator = shift_info()
        self._taxis = [
            taxi_process(taxi_id_generator,shift_info_generator)
            for i in range(num_taxis)]
        self._prepare_run()

    def _prepare_run(self):
        for t in self._taxis:
            while True:
                try:
                    e = next(t)
                    self._time_points.put(e)
                except:
                    break

    def run(self):
        sim_time = 0
        while sim_time < 24:
            if self._time_points.empty():
                break
            p = self._time_points.get()
            sim_time = p.time
            print(p)

# %% [markdown]
# Example Code 125

# %%
sim = Simulator(1000)
sim.run()
# Out:
# TimePoint(taxi_id=54, name='start shift', time=0)
# TimePoint(taxi_id=543, name='start shift', time=0)
# TimePoint(taxi_id=363, name='start shift', time=0)
# TimePoint(taxi_id=177, name='start shift', time=0)
# TimePoint(taxi_id=183, name='start shift', time=0)
# TimePoint(taxi_id=653, name='start shift', time=0)
# TimePoint(taxi_id=747, name='start shift', time=0)
# TimePoint(taxi_id=661, name='start shift', time=0)
# TimePoint(taxi_id=812, name='start shift', time=0)
# TimePoint(taxi_id=930, name='start shift', time=0)
# TimePoint(taxi_id=424, name='start shift', time=0)
# TimePoint(taxi_id=339, name='start shift', time=0)
# TimePoint(taxi_id=253, name='start shift', time=0)
# TimePoint(taxi_id=58, name='start shift', time=0)
# TimePoint(taxi_id=447, name='start shift', time=0)
# TimePoint(taxi_id=637, name='start shift', time=0)
# TimePoint(taxi_id=141, name='start shift', time=0)
# TimePoint(taxi_id=719, name='start shift', time=0)
# TimePoint(taxi_id=257, name='start shift', time=0)
# TimePoint(taxi_id=881, name='start shift', time=0)
# TimePoint(taxi_id=907, name='start shift', time=0)
# TimePoint(taxi_id=193, name='start shift', time=0)
# TimePoint(taxi_id=445, name='start shift', time=0)
# TimePoint(taxi_id=74, name='start shift', time=0)
# TimePoint(taxi_id=466, name='start shift', time=0)
# TimePoint(taxi_id=699, name='start shift', time=0)
# TimePoint(taxi_id=811, name='start shift', time=0)
# TimePoint(taxi_id=510, name='start shift', time=0)
# TimePoint(taxi_id=878, name='start shift', time=0)
# TimePoint(taxi_id=428, name='start shift', time=0)
# TimePoint(taxi_id=696, name='start shift', time=0)
# TimePoint(taxi_id=613, name='start shift', time=0)
# TimePoint(taxi_id=915, name='start shift', time=0)
# TimePoint(taxi_id=749, name='start shift', time=0)
# TimePoint(taxi_id=869, name='start shift', time=0)
# TimePoint(taxi_id=379, name='start shift', time=0)
# TimePoint(taxi_id=570, name='start shift', time=0)
# TimePoint(taxi_id=62, name='start shift', time=0)
# TimePoint(taxi_id=166, name='start shift', time=0)
# TimePoint(taxi_id=130, name='start shift', time=0)
# TimePoint(taxi_id=857, name='start shift', time=0)
# TimePoint(taxi_id=358, name='start shift', time=0)
# TimePoint(taxi_id=50, name='start shift', time=0)
# TimePoint(taxi_id=621, name='start shift', time=0)
# TimePoint(taxi_id=995, name='start shift', time=0)
# TimePoint(taxi_id=687, name='start shift', time=0)
# TimePoint(taxi_id=222, name='start shift', time=0)
# TimePoint(taxi_id=256, name='start shift', time=0)
# TimePoint(taxi_id=935, name='start shift', time=0)
# TimePoint(taxi_id=862, name='start shift', time=0)
# TimePoint(taxi_id=387, name='start shift', time=0)
# TimePoint(taxi_id=966, name='start shift', time=0)
# TimePoint(taxi_id=768, name='start shift', time=0)
# TimePoint(taxi_id=928, name='start shift', time=0)
# TimePoint(taxi_id=93, name='start shift', time=0)
# TimePoint(taxi_id=63, name='start shift', time=0)
# TimePoint(taxi_id=465, name='start shift', time=0)
# TimePoint(taxi_id=590, name='start shift', time=0)
# TimePoint(taxi_id=344, name='start shift', time=0)
# TimePoint(taxi_id=324, name='start shift', time=0)
# TimePoint(taxi_id=43, name='start shift', time=0)
# TimePoint(taxi_id=121, name='start shift', time=0)
# TimePoint(taxi_id=512, name='start shift', time=0)
# TimePoint(taxi_id=838, name='start shift', time=0)
# TimePoint(taxi_id=893, name='start shift', time=0)
# TimePoint(taxi_id=525, name='start shift', time=0)
# TimePoint(taxi_id=611, name='start shift', time=0)
# TimePoint(taxi_id=573, name='start shift', time=0)
# TimePoint(taxi_id=929, name='start shift', time=0)
# TimePoint(taxi_id=744, name='start shift', time=0)
# TimePoint(taxi_id=268, name='start shift', time=0)
# TimePoint(taxi_id=37, name='start shift', time=0)
# TimePoint(taxi_id=277, name='start shift', time=0)
# TimePoint(taxi_id=42, name='start shift', time=0)
# TimePoint(taxi_id=718, name='start shift', time=0)
# TimePoint(taxi_id=856, name='start shift', time=0)
# TimePoint(taxi_id=918, name='start shift', time=0)
# TimePoint(taxi_id=57, name='start shift', time=0)
# TimePoint(taxi_id=983, name='start shift', time=0)
# TimePoint(taxi_id=393, name='start shift', time=0)
# TimePoint(taxi_id=541, name='start shift', time=0)
# TimePoint(taxi_id=721, name='start shift', time=0)
# TimePoint(taxi_id=69, name='start shift', time=0)
# TimePoint(taxi_id=832, name='start shift', time=0)
# TimePoint(taxi_id=408, name='start shift', time=0)
# TimePoint(taxi_id=95, name='start shift', time=0)
# TimePoint(taxi_id=270, name='start shift', time=0)
# TimePoint(taxi_id=575, name='start shift', time=0)
# TimePoint(taxi_id=407, name='start shift', time=0)
# TimePoint(taxi_id=850, name='start shift', time=0)
# TimePoint(taxi_id=479, name='start shift', time=0)
# TimePoint(taxi_id=128, name='start shift', time=0)
# TimePoint(taxi_id=395, name='start shift', time=0)
# TimePoint(taxi_id=688, name='start shift', time=0)
# TimePoint(taxi_id=671, name='start shift', time=0)
# TimePoint(taxi_id=954, name='start shift', time=0)
# TimePoint(taxi_id=412, name='start shift', time=0)
# TimePoint(taxi_id=406, name='start shift', time=0)
# TimePoint(taxi_id=191, name='start shift', time=0)
# TimePoint(taxi_id=242, name='start shift', time=0)
# TimePoint(taxi_id=610, name='start shift', time=0)
# TimePoint(taxi_id=516, name='start shift', time=0)
# TimePoint(taxi_id=574, name='start shift', time=0)
# TimePoint(taxi_id=48, name='start shift', time=0)
# TimePoint(taxi_id=217, name='start shift', time=0)
# TimePoint(taxi_id=9, name='start shift', time=0)
# TimePoint(taxi_id=431, name='start shift', time=0)
# TimePoint(taxi_id=403, name='start shift', time=0)
# TimePoint(taxi_id=950, name='start shift', time=0)
# TimePoint(taxi_id=955, name='start shift', time=0)
# TimePoint(taxi_id=886, name='start shift', time=0)
# TimePoint(taxi_id=292, name='start shift', time=0)
# TimePoint(taxi_id=795, name='start shift', time=0)
# TimePoint(taxi_id=110, name='start shift', time=0)
# TimePoint(taxi_id=728, name='start shift', time=0)
# TimePoint(taxi_id=529, name='start shift', time=0)
# TimePoint(taxi_id=6, name='start shift', time=0)
# TimePoint(taxi_id=774, name='start shift', time=0)
# TimePoint(taxi_id=374, name='start shift', time=0)
# TimePoint(taxi_id=600, name='start shift', time=0)
# TimePoint(taxi_id=31, name='start shift', time=0)
# TimePoint(taxi_id=318, name='start shift', time=0)
# TimePoint(taxi_id=897, name='start shift', time=0)
# TimePoint(taxi_id=76, name='start shift', time=0)
# TimePoint(taxi_id=767, name='start shift', time=0)
# TimePoint(taxi_id=157, name='start shift', time=0)
# TimePoint(taxi_id=701, name='start shift', time=0)
# TimePoint(taxi_id=26, name='start shift', time=0)
# TimePoint(taxi_id=373, name='start shift', time=0)
# TimePoint(taxi_id=231, name='start shift', time=0)
# TimePoint(taxi_id=441, name='start shift', time=0)
# TimePoint(taxi_id=873, name='start shift', time=0)
# TimePoint(taxi_id=173, name='start shift', time=0)
# TimePoint(taxi_id=975, name='start shift', time=0)
# TimePoint(taxi_id=355, name='start shift', time=0)
# TimePoint(taxi_id=665, name='start shift', time=0)
# TimePoint(taxi_id=781, name='start shift', time=0)
# TimePoint(taxi_id=592, name='start shift', time=0)
# TimePoint(taxi_id=422, name='start shift', time=0)
# TimePoint(taxi_id=961, name='start shift', time=0)
# TimePoint(taxi_id=86, name='start shift', time=0)
# TimePoint(taxi_id=982, name='start shift', time=0)
# TimePoint(taxi_id=537, name='start shift', time=0)
# TimePoint(taxi_id=244, name='start shift', time=0)
# TimePoint(taxi_id=176, name='start shift', time=0)
# TimePoint(taxi_id=720, name='start shift', time=0)
# TimePoint(taxi_id=889, name='start shift', time=0)
# TimePoint(taxi_id=283, name='start shift', time=0)
# TimePoint(taxi_id=334, name='start shift', time=0)
# TimePoint(taxi_id=947, name='start shift', time=0)
# TimePoint(taxi_id=766, name='start shift', time=0)
# TimePoint(taxi_id=870, name='start shift', time=0)
# TimePoint(taxi_id=506, name='start shift', time=0)
# TimePoint(taxi_id=440, name='start shift', time=0)
# TimePoint(taxi_id=988, name='start shift', time=0)
# TimePoint(taxi_id=560, name='start shift', time=0)
# TimePoint(taxi_id=325, name='start shift', time=0)
# TimePoint(taxi_id=284, name='start shift', time=0)
# TimePoint(taxi_id=442, name='start shift', time=0)
# TimePoint(taxi_id=976, name='start shift', time=0)
# TimePoint(taxi_id=285, name='start shift', time=0)
# TimePoint(taxi_id=437, name='start shift', time=0)
# TimePoint(taxi_id=108, name='start shift', time=0)
# TimePoint(taxi_id=709, name='start shift', time=0)
# TimePoint(taxi_id=582, name='start shift', time=0)
# TimePoint(taxi_id=122, name='start shift', time=0)
# TimePoint(taxi_id=220, name='start shift', time=0)
# TimePoint(taxi_id=786, name='start shift', time=0)
# TimePoint(taxi_id=639, name='start shift', time=0)
# TimePoint(taxi_id=214, name='start shift', time=0)
# TimePoint(taxi_id=364, name='start shift', time=0)
# TimePoint(taxi_id=15, name='start shift', time=0)
# TimePoint(taxi_id=698, name='start shift', time=0)
# TimePoint(taxi_id=595, name='start shift', time=0)
# TimePoint(taxi_id=685, name='start shift', time=0)
# TimePoint(taxi_id=40, name='start shift', time=0)
# TimePoint(taxi_id=36, name='start shift', time=0)
# TimePoint(taxi_id=677, name='start shift', time=0)
# TimePoint(taxi_id=416, name='start shift', time=0)
# TimePoint(taxi_id=336, name='start shift', time=0)
# TimePoint(taxi_id=736, name='start shift', time=0)
# TimePoint(taxi_id=239, name='start shift', time=0)
# TimePoint(taxi_id=111, name='start shift', time=0)
# TimePoint(taxi_id=733, name='start shift', time=0)
# TimePoint(taxi_id=181, name='start shift', time=0)
# TimePoint(taxi_id=551, name='start shift', time=0)
# TimePoint(taxi_id=941, name='start shift', time=0)
# TimePoint(taxi_id=764, name='start shift', time=0)
# TimePoint(taxi_id=638, name='start shift', time=0)
# TimePoint(taxi_id=204, name='start shift', time=0)
# TimePoint(taxi_id=751, name='start shift', time=0)
# TimePoint(taxi_id=630, name='start shift', time=0)
# TimePoint(taxi_id=500, name='start shift', time=0)
# TimePoint(taxi_id=450, name='start shift', time=0)
# TimePoint(taxi_id=127, name='start shift', time=0)
# TimePoint(taxi_id=518, name='start shift', time=0)
# TimePoint(taxi_id=75, name='start shift', time=0)
# TimePoint(taxi_id=834, name='start shift', time=0)
# TimePoint(taxi_id=153, name='start shift', time=0)
# TimePoint(taxi_id=87, name='start shift', time=0)
# TimePoint(taxi_id=467, name='start shift', time=0)
# TimePoint(taxi_id=349, name='start shift', time=0)
# TimePoint(taxi_id=535, name='start shift', time=0)
# TimePoint(taxi_id=250, name='start shift', time=0)
# TimePoint(taxi_id=425, name='start shift', time=0)
# TimePoint(taxi_id=956, name='start shift', time=0)
# TimePoint(taxi_id=936, name='start shift', time=0)
# TimePoint(taxi_id=992, name='start shift', time=0)
# TimePoint(taxi_id=468, name='start shift', time=0)
# TimePoint(taxi_id=46, name='start shift', time=0)
# TimePoint(taxi_id=125, name='start shift', time=0)
# TimePoint(taxi_id=660, name='start shift', time=0)
# TimePoint(taxi_id=139, name='start shift', time=0)
# TimePoint(taxi_id=505, name='start shift', time=0)
# TimePoint(taxi_id=61, name='start shift', time=0)
# TimePoint(taxi_id=690, name='start shift', time=0)
# TimePoint(taxi_id=891, name='start shift', time=0)
# TimePoint(taxi_id=391, name='start shift', time=0)
# TimePoint(taxi_id=842, name='start shift', time=0)
# TimePoint(taxi_id=126, name='start shift', time=0)
# TimePoint(taxi_id=410, name='start shift', time=0)
# TimePoint(taxi_id=759, name='start shift', time=0)
# TimePoint(taxi_id=912, name='start shift', time=0)
# TimePoint(taxi_id=788, name='start shift', time=0)
# TimePoint(taxi_id=90, name='start shift', time=0)
# TimePoint(taxi_id=682, name='start shift', time=0)
# TimePoint(taxi_id=101, name='start shift', time=0)
# TimePoint(taxi_id=797, name='start shift', time=0)
# TimePoint(taxi_id=618, name='start shift', time=0)
# TimePoint(taxi_id=68, name='start shift', time=0)
# TimePoint(taxi_id=607, name='start shift', time=0)
# TimePoint(taxi_id=753, name='start shift', time=0)
# TimePoint(taxi_id=787, name='start shift', time=0)
# TimePoint(taxi_id=134, name='start shift', time=0)
# TimePoint(taxi_id=624, name='start shift', time=0)
# TimePoint(taxi_id=672, name='start shift', time=0)
# TimePoint(taxi_id=356, name='start shift', time=0)
# TimePoint(taxi_id=404, name='start shift', time=0)
# TimePoint(taxi_id=18, name='start shift', time=0)
# TimePoint(taxi_id=669, name='start shift', time=0)
# TimePoint(taxi_id=186, name='start shift', time=0)
# TimePoint(taxi_id=432, name='start shift', time=0)
# TimePoint(taxi_id=52, name='start shift', time=0)
# TimePoint(taxi_id=211, name='start shift', time=0)
# TimePoint(taxi_id=5, name='start shift', time=0)
# TimePoint(taxi_id=896, name='start shift', time=0)
# TimePoint(taxi_id=280, name='start shift', time=0)
# TimePoint(taxi_id=949, name='start shift', time=0)
# TimePoint(taxi_id=740, name='start shift', time=0)
# TimePoint(taxi_id=430, name='start shift', time=0)
# TimePoint(taxi_id=296, name='start shift', time=0)
# TimePoint(taxi_id=323, name='start shift', time=0)
# TimePoint(taxi_id=710, name='start shift', time=0)
# TimePoint(taxi_id=859, name='start shift', time=0)
# TimePoint(taxi_id=763, name='start shift', time=0)
# TimePoint(taxi_id=670, name='start shift', time=0)
# TimePoint(taxi_id=979, name='start shift', time=0)
# TimePoint(taxi_id=769, name='start shift', time=0)
# TimePoint(taxi_id=527, name='start shift', time=0)
# TimePoint(taxi_id=848, name='start shift', time=0)
# TimePoint(taxi_id=405, name='start shift', time=0)
# TimePoint(taxi_id=971, name='start shift', time=0)
# TimePoint(taxi_id=33, name='start shift', time=0)
# TimePoint(taxi_id=133, name='start shift', time=0)
# TimePoint(taxi_id=38, name='start shift', time=0)
# TimePoint(taxi_id=542, name='start shift', time=0)
# TimePoint(taxi_id=568, name='start shift', time=0)
# TimePoint(taxi_id=538, name='start shift', time=0)
# TimePoint(taxi_id=922, name='start shift', time=0)
# TimePoint(taxi_id=73, name='start shift', time=0)
# TimePoint(taxi_id=575, name='pick up', time=0.03333333333333333)
# TimePoint(taxi_id=787, name='pick up', time=0.03333333333333333)
# TimePoint(taxi_id=211, name='pick up', time=0.03333333333333333)
# TimePoint(taxi_id=893, name='pick up', time=0.05)
# TimePoint(taxi_id=108, name='pick up', time=0.05)
# TimePoint(taxi_id=87, name='pick up', time=0.05)
# TimePoint(taxi_id=788, name='pick up', time=0.05)
# TimePoint(taxi_id=886, name='pick up', time=0.05)
# TimePoint(taxi_id=141, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=857, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=590, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=728, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=889, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=204, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=61, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=356, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=653, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=121, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=277, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=37, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=479, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=954, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=191, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=242, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=9, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=403, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=873, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=506, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=437, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=639, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=551, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=638, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=660, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=682, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=753, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=404, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=763, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=848, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=405, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=73, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=570, name='pick up', time=0.1)
# TimePoint(taxi_id=862, name='pick up', time=0.1)
# TimePoint(taxi_id=256, name='pick up', time=0.1)
# TimePoint(taxi_id=935, name='pick up', time=0.1)
# TimePoint(taxi_id=395, name='pick up', time=0.1)
# TimePoint(taxi_id=955, name='pick up', time=0.1)
# TimePoint(taxi_id=537, name='pick up', time=0.1)
# TimePoint(taxi_id=244, name='pick up', time=0.1)
# TimePoint(taxi_id=947, name='pick up', time=0.1)
# TimePoint(taxi_id=976, name='pick up', time=0.1)
# TimePoint(taxi_id=450, name='pick up', time=0.1)
# TimePoint(taxi_id=912, name='pick up', time=0.1)
# TimePoint(taxi_id=101, name='pick up', time=0.1)
# TimePoint(taxi_id=133, name='pick up', time=0.1)
# TimePoint(taxi_id=542, name='pick up', time=0.1)
# TimePoint(taxi_id=661, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=747, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=930, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=339, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=699, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=428, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=222, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=93, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=512, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=983, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=721, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=270, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=128, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=688, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=54, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=6, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=529, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=318, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=373, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=665, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=982, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=870, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=560, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=292, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=220, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=239, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=336, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=941, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=595, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=518, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=630, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=467, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=535, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=250, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=46, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=90, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=618, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=891, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=134, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=186, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=5, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=949, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=527, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=922, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=424, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=811, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=613, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=696, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=166, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=62, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=995, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=966, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=465, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=43, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=838, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=611, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=918, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=850, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=671, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=217, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=374, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=31, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=701, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=781, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=592, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=422, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=86, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=582, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=285, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=36, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=416, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=685, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=733, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=956, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=468, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=936, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=505, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=410, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=68, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=672, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=669, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=296, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=323, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=979, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=670, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=538, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=445, name='pick up', time=0.15)
# TimePoint(taxi_id=74, name='pick up', time=0.15)
# TimePoint(taxi_id=510, name='pick up', time=0.15)
# TimePoint(taxi_id=915, name='pick up', time=0.15)
# TimePoint(taxi_id=749, name='pick up', time=0.15)
# TimePoint(taxi_id=50, name='pick up', time=0.15)
# TimePoint(taxi_id=687, name='pick up', time=0.15)
# TimePoint(taxi_id=344, name='pick up', time=0.15)
# TimePoint(taxi_id=543, name='pick up', time=0.15)
# TimePoint(taxi_id=718, name='pick up', time=0.15)
# TimePoint(taxi_id=268, name='pick up', time=0.15)
# TimePoint(taxi_id=541, name='pick up', time=0.15)
# TimePoint(taxi_id=744, name='pick up', time=0.15)
# TimePoint(taxi_id=95, name='pick up', time=0.15)
# TimePoint(taxi_id=412, name='pick up', time=0.15)
# TimePoint(taxi_id=832, name='pick up', time=0.15)
# TimePoint(taxi_id=574, name='pick up', time=0.15)
# TimePoint(taxi_id=897, name='pick up', time=0.15)
# TimePoint(taxi_id=231, name='pick up', time=0.15)
# TimePoint(taxi_id=26, name='pick up', time=0.15)
# TimePoint(taxi_id=283, name='pick up', time=0.15)
# TimePoint(taxi_id=334, name='pick up', time=0.15)
# TimePoint(taxi_id=975, name='pick up', time=0.15)
# TimePoint(taxi_id=709, name='pick up', time=0.15)
# TimePoint(taxi_id=786, name='pick up', time=0.15)
# TimePoint(taxi_id=15, name='pick up', time=0.15)
# TimePoint(taxi_id=736, name='pick up', time=0.15)
# TimePoint(taxi_id=764, name='pick up', time=0.15)
# TimePoint(taxi_id=153, name='pick up', time=0.15)
# TimePoint(taxi_id=992, name='pick up', time=0.15)
# TimePoint(taxi_id=52, name='pick up', time=0.15)
# TimePoint(taxi_id=430, name='pick up', time=0.15)
# TimePoint(taxi_id=971, name='pick up', time=0.15)
# TimePoint(taxi_id=740, name='pick up', time=0.15)
# TimePoint(taxi_id=280, name='pick up', time=0.15)
# TimePoint(taxi_id=769, name='pick up', time=0.15)
# TimePoint(taxi_id=568, name='pick up', time=0.15)
# TimePoint(taxi_id=812, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=881, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=466, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=177, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=379, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=130, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=621, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=358, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=929, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=408, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=928, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=516, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=431, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=795, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=110, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=600, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=774, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=76, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=157, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=441, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=173, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=440, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=988, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=442, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=181, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=111, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=125, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=139, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=842, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=284, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=126, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=797, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=624, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=432, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=710, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=896, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=33, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=58, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=719, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=907, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=363, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=573, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=856, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=48, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=355, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=766, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=325, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=122, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=214, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=698, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=127, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=75, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=500, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=425, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=751, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=759, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=38, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=183, name='pick up', time=0.2)
# TimePoint(taxi_id=447, name='pick up', time=0.2)
# TimePoint(taxi_id=257, name='pick up', time=0.2)
# TimePoint(taxi_id=253, name='pick up', time=0.2)
# TimePoint(taxi_id=869, name='pick up', time=0.2)
# TimePoint(taxi_id=768, name='pick up', time=0.2)
# TimePoint(taxi_id=324, name='pick up', time=0.2)
# TimePoint(taxi_id=406, name='pick up', time=0.2)
# TimePoint(taxi_id=610, name='pick up', time=0.2)
# TimePoint(taxi_id=720, name='pick up', time=0.2)
# TimePoint(taxi_id=364, name='pick up', time=0.2)
# TimePoint(taxi_id=18, name='pick up', time=0.2)
# TimePoint(taxi_id=637, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=193, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=878, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=63, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=407, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=950, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=767, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=961, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=40, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=42, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=57, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=393, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=69, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=176, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=349, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=387, name='pick up', time=0.25)
# TimePoint(taxi_id=834, name='pick up', time=0.25)
# TimePoint(taxi_id=690, name='pick up', time=0.25)
# TimePoint(taxi_id=607, name='pick up', time=0.25)
# TimePoint(taxi_id=525, name='pick up', time=0.26666666666666666)
# TimePoint(taxi_id=391, name='pick up', time=0.26666666666666666)
# TimePoint(taxi_id=859, name='pick up', time=0.26666666666666666)
# TimePoint(taxi_id=677, name='pick up', time=0.2833333333333333)
# TimePoint(taxi_id=9, name='drop off', time=0.6666666666666667)
# TimePoint(taxi_id=954, name='drop off', time=0.6833333333333333)
# TimePoint(taxi_id=787, name='drop off', time=0.7)
# TimePoint(taxi_id=500, name='drop off', time=0.7000000000000001)
# TimePoint(taxi_id=975, name='drop off', time=0.7166666666666667)
# TimePoint(taxi_id=46, name='drop off', time=0.7166666666666667)
# TimePoint(taxi_id=323, name='drop off', time=0.7166666666666667)
# TimePoint(taxi_id=935, name='drop off', time=0.7333333333333333)
# TimePoint(taxi_id=947, name='drop off', time=0.7333333333333333)
# TimePoint(taxi_id=670, name='drop off', time=0.7333333333333333)
# TimePoint(taxi_id=512, name='drop off', time=0.7333333333333334)
# TimePoint(taxi_id=108, name='drop off', time=0.7333333333333334)
# TimePoint(taxi_id=128, name='drop off', time=0.75)
# TimePoint(taxi_id=682, name='drop off', time=0.75)
# TimePoint(taxi_id=211, name='drop off', time=0.7666666666666666)
# TimePoint(taxi_id=121, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=983, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=688, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=971, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=838, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=277, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=6, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=250, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=512, name='pick up', time=0.7833333333333334)
# TimePoint(taxi_id=696, name='drop off', time=0.7999999999999999)
# TimePoint(taxi_id=935, name='pick up', time=0.7999999999999999)
# TimePoint(taxi_id=893, name='drop off', time=0.8)
# TimePoint(taxi_id=108, name='pick up', time=0.8)
# TimePoint(taxi_id=15, name='drop off', time=0.8)
# TimePoint(taxi_id=5, name='drop off', time=0.8)
# TimePoint(taxi_id=570, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=428, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=857, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=575, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=873, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=889, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=239, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=848, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=500, name='pick up', time=0.8166666666666668)
# TimePoint(taxi_id=886, name='drop off', time=0.8166666666666668)
# TimePoint(taxi_id=653, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=719, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=541, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=832, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=574, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=6, name='pick up', time=0.8333333333333334)
# TimePoint(taxi_id=897, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=373, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=975, name='pick up', time=0.8333333333333334)
# TimePoint(taxi_id=941, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=323, name='pick up', time=0.8333333333333334)
# TimePoint(taxi_id=379, name='drop off', time=0.85)
# TimePoint(taxi_id=856, name='drop off', time=0.85)
# TimePoint(taxi_id=954, name='pick up', time=0.85)
# TimePoint(taxi_id=86, name='drop off', time=0.85)
# TimePoint(taxi_id=283, name='drop off', time=0.85)
# TimePoint(taxi_id=870, name='drop off', time=0.85)
# TimePoint(taxi_id=220, name='drop off', time=0.85)
# TimePoint(taxi_id=9, name='pick up', time=0.8500000000000001)
# TimePoint(taxi_id=405, name='drop off', time=0.8500000000000001)
# TimePoint(taxi_id=62, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=358, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=850, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=440, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=582, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=277, name='pick up', time=0.8666666666666667)
# TimePoint(taxi_id=688, name='pick up', time=0.8666666666666667)
# TimePoint(taxi_id=955, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=551, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=153, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=87, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=660, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=404, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=363, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=570, name='pick up', time=0.8833333333333333)
# TimePoint(taxi_id=995, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=128, name='pick up', time=0.8833333333333333)
# TimePoint(taxi_id=48, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=736, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=68, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=211, name='pick up', time=0.8833333333333333)
# TimePoint(taxi_id=896, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=54, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=403, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=318, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=753, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=869, name='drop off', time=0.8999999999999999)
# TimePoint(taxi_id=768, name='drop off', time=0.8999999999999999)
# TimePoint(taxi_id=57, name='drop off', time=0.8999999999999999)
# TimePoint(taxi_id=408, name='drop off', time=0.8999999999999999)
# TimePoint(taxi_id=139, name='drop off', time=0.8999999999999999)
# TimePoint(taxi_id=166, name='drop off', time=0.9)
# TimePoint(taxi_id=222, name='drop off', time=0.9)
# TimePoint(taxi_id=407, name='drop off', time=0.9)
# TimePoint(taxi_id=191, name='drop off', time=0.9)
# TimePoint(taxi_id=873, name='pick up', time=0.9)
# TimePoint(taxi_id=592, name='drop off', time=0.9)
# TimePoint(taxi_id=334, name='drop off', time=0.9)
# TimePoint(taxi_id=204, name='drop off', time=0.9)
# TimePoint(taxi_id=61, name='drop off', time=0.9)
# TimePoint(taxi_id=912, name='drop off', time=0.9)
# TimePoint(taxi_id=101, name='drop off', time=0.9)
# TimePoint(taxi_id=428, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=728, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=76, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=781, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=325, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=239, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=956, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=682, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=699, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=270, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=832, name='pick up', time=0.9166666666666667)
# TimePoint(taxi_id=560, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=292, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=46, name='pick up', time=0.9166666666666667)
# TimePoint(taxi_id=891, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=18, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=971, name='pick up', time=0.9166666666666667)
# TimePoint(taxi_id=613, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=966, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=929, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=718, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=574, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=701, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=422, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=947, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=709, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=639, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=336, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=941, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=759, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=787, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=669, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=5, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=430, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=949, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=670, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=403, name='pick up', time=0.9333333333333335)
# TimePoint(taxi_id=878, name='drop off', time=0.95)
# TimePoint(taxi_id=62, name='pick up', time=0.95)
# TimePoint(taxi_id=256, name='drop off', time=0.95)
# TimePoint(taxi_id=857, name='pick up', time=0.95)
# TimePoint(taxi_id=856, name='pick up', time=0.95)
# TimePoint(taxi_id=406, name='drop off', time=0.95)
# TimePoint(taxi_id=86, name='pick up', time=0.95)
# TimePoint(taxi_id=220, name='pick up', time=0.95)
# TimePoint(taxi_id=542, name='drop off', time=0.95)
# TimePoint(taxi_id=661, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=339, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=687, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=121, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=37, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=54, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=373, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=122, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=786, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=69, name='drop off', time=0.9666666666666666)
# TimePoint(taxi_id=74, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=510, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=621, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=50, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=893, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=838, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=575, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=537, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=982, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=285, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=437, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=15, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=250, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=763, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=405, name='pick up', time=0.9666666666666668)
# TimePoint(taxi_id=358, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=465, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=244, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=440, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=468, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=936, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=624, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=848, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=133, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=183, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=749, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=573, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=268, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=983, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=955, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=231, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=592, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=665, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=334, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=214, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=698, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=886, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=467, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=349, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=769, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=850, name='pick up', time=0.9999999999999999)
# TimePoint(taxi_id=582, name='pick up', time=0.9999999999999999)
# TimePoint(taxi_id=139, name='pick up', time=0.9999999999999999)
# TimePoint(taxi_id=177, name='drop off', time=1.0)
# TimePoint(taxi_id=696, name='pick up', time=1.0)
# TimePoint(taxi_id=166, name='pick up', time=1.0)
# TimePoint(taxi_id=387, name='drop off', time=1.0)
# TimePoint(taxi_id=611, name='drop off', time=1.0)
# TimePoint(taxi_id=744, name='drop off', time=1.0)
# TimePoint(taxi_id=395, name='drop off', time=1.0)
# TimePoint(taxi_id=242, name='drop off', time=1.0)
# TimePoint(taxi_id=283, name='pick up', time=1.0)
# TimePoint(taxi_id=506, name='drop off', time=1.0)
# TimePoint(taxi_id=988, name='drop off', time=1.0)
# TimePoint(taxi_id=551, name='pick up', time=1.0)
# TimePoint(taxi_id=733, name='drop off', time=1.0)
# TimePoint(taxi_id=690, name='drop off', time=1.0)
# TimePoint(taxi_id=186, name='drop off', time=1.0)
# TimePoint(taxi_id=527, name='drop off', time=1.0)
# TimePoint(taxi_id=896, name='pick up', time=1.0)
# TimePoint(taxi_id=445, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=878, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=915, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=379, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=869, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=363, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=995, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=862, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=344, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=63, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=918, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=721, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=479, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=600, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=701, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=441, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=720, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=639, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=40, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=204, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=518, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=87, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=751, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=842, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=410, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=68, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=404, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=710, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=38, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=699, name='pick up', time=1.0166666666666668)
# TimePoint(taxi_id=37, name='pick up', time=1.0166666666666668)
# TimePoint(taxi_id=292, name='pick up', time=1.0166666666666668)
# TimePoint(taxi_id=637, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=543, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=93, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=26, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=781, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=889, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=766, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=736, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=638, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=922, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=257, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=719, name='pick up', time=1.0333333333333334)
# TimePoint(taxi_id=811, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=610, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=110, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=897, name='pick up', time=1.0333333333333334)
# TimePoint(taxi_id=181, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=61, name='pick up', time=1.0333333333333334)
# TimePoint(taxi_id=430, name='pick up', time=1.0333333333333334)
# TimePoint(taxi_id=296, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=408, name='pick up', time=1.0499999999999998)
# TimePoint(taxi_id=424, name='drop off', time=1.05)
# TimePoint(taxi_id=141, name='drop off', time=1.05)
# TimePoint(taxi_id=193, name='drop off', time=1.05)
# TimePoint(taxi_id=466, name='drop off', time=1.05)
# TimePoint(taxi_id=907, name='drop off', time=1.05)
# TimePoint(taxi_id=256, name='pick up', time=1.05)
# TimePoint(taxi_id=590, name='drop off', time=1.05)
# TimePoint(taxi_id=541, name='pick up', time=1.05)
# TimePoint(taxi_id=270, name='pick up', time=1.05)
# TimePoint(taxi_id=407, name='pick up', time=1.05)
# TimePoint(taxi_id=529, name='drop off', time=1.05)
# TimePoint(taxi_id=537, name='pick up', time=1.05)
# TimePoint(taxi_id=560, name='pick up', time=1.05)
# TimePoint(taxi_id=709, name='pick up', time=1.05)
# TimePoint(taxi_id=764, name='drop off', time=1.05)
# TimePoint(taxi_id=75, name='drop off', time=1.05)
# TimePoint(taxi_id=153, name='pick up', time=1.05)
# TimePoint(taxi_id=630, name='drop off', time=1.05)
# TimePoint(taxi_id=891, name='pick up', time=1.05)
# TimePoint(taxi_id=753, name='pick up', time=1.05)
# TimePoint(taxi_id=672, name='drop off', time=1.05)
# TimePoint(taxi_id=859, name='drop off', time=1.05)
# ...
# TimePoint(taxi_id=196, name='pick up', time=23.450000000000003)
# TimePoint(taxi_id=548, name='pick up', time=23.450000000000003)
# TimePoint(taxi_id=900, name='drop off', time=23.450000000000003)
# TimePoint(taxi_id=462, name='pick up', time=23.450000000000003)
# TimePoint(taxi_id=814, name='pick up', time=23.450000000000006)
# TimePoint(taxi_id=659, name='end_shift', time=23.450000000000006)
# TimePoint(taxi_id=823, name='pick up', time=23.450000000000006)
# TimePoint(taxi_id=274, name='drop off', time=23.45000000000002)
# TimePoint(taxi_id=651, name='pick up', time=23.46666666666666)
# TimePoint(taxi_id=115, name='drop off', time=23.466666666666665)
# TimePoint(taxi_id=306, name='drop off', time=23.466666666666665)
# TimePoint(taxi_id=996, name='drop off', time=23.466666666666665)
# TimePoint(taxi_id=689, name='drop off', time=23.46666666666667)
# TimePoint(taxi_id=149, name='drop off', time=23.46666666666667)
# TimePoint(taxi_id=255, name='drop off', time=23.46666666666667)
# TimePoint(taxi_id=172, name='end_shift', time=23.466666666666676)
# TimePoint(taxi_id=119, name='end_shift', time=23.466666666666676)
# TimePoint(taxi_id=902, name='end_shift', time=23.466666666666676)
# TimePoint(taxi_id=997, name='pick up', time=23.46666666666668)
# TimePoint(taxi_id=616, name='drop off', time=23.483333333333324)
# TimePoint(taxi_id=707, name='end_shift', time=23.483333333333327)
# TimePoint(taxi_id=487, name='drop off', time=23.483333333333327)
# TimePoint(taxi_id=819, name='pick up', time=23.48333333333333)
# TimePoint(taxi_id=469, name='pick up', time=23.48333333333333)
# TimePoint(taxi_id=348, name='drop off', time=23.48333333333333)
# TimePoint(taxi_id=633, name='drop off', time=23.48333333333333)
# TimePoint(taxi_id=782, name='end_shift', time=23.48333333333333)
# TimePoint(taxi_id=794, name='pick up', time=23.483333333333334)
# TimePoint(taxi_id=255, name='pick up', time=23.483333333333334)
# TimePoint(taxi_id=312, name='end_shift', time=23.483333333333338)
# TimePoint(taxi_id=117, name='pick up', time=23.483333333333338)
# TimePoint(taxi_id=254, name='drop off', time=23.483333333333338)
# TimePoint(taxi_id=894, name='end_shift', time=23.483333333333338)
# TimePoint(taxi_id=30, name='end_shift', time=23.48333333333335)
# TimePoint(taxi_id=990, name='pick up', time=23.499999999999996)
# TimePoint(taxi_id=316, name='drop off', time=23.5)
# TimePoint(taxi_id=115, name='pick up', time=23.5)
# TimePoint(taxi_id=550, name='pick up', time=23.500000000000004)
# TimePoint(taxi_id=104, name='drop off', time=23.500000000000004)
# TimePoint(taxi_id=322, name='end_shift', time=23.50000000000001)
# TimePoint(taxi_id=778, name='drop off', time=23.516666666666666)
# TimePoint(taxi_id=972, name='drop off', time=23.516666666666666)
# TimePoint(taxi_id=927, name='pick up', time=23.516666666666673)
# TimePoint(taxi_id=199, name='end_shift', time=23.533333333333328)
# TimePoint(taxi_id=213, name='drop off', time=23.53333333333333)
# TimePoint(taxi_id=752, name='drop off', time=23.533333333333335)
# TimePoint(taxi_id=282, name='end_shift', time=23.533333333333335)
# TimePoint(taxi_id=968, name='drop off', time=23.53333333333334)
# TimePoint(taxi_id=493, name='end_shift', time=23.533333333333346)
# TimePoint(taxi_id=221, name='drop off', time=23.549999999999994)
# TimePoint(taxi_id=633, name='pick up', time=23.549999999999997)
# TimePoint(taxi_id=348, name='pick up', time=23.549999999999997)
# TimePoint(taxi_id=265, name='pick up', time=23.55)
# TimePoint(taxi_id=53, name='drop off', time=23.55)
# TimePoint(taxi_id=132, name='pick up', time=23.55)
# TimePoint(taxi_id=383, name='drop off', time=23.55)
# TimePoint(taxi_id=306, name='end_shift', time=23.55)
# TimePoint(taxi_id=444, name='drop off', time=23.550000000000004)
# TimePoint(taxi_id=254, name='pick up', time=23.550000000000004)
# TimePoint(taxi_id=227, name='drop off', time=23.550000000000008)
# TimePoint(taxi_id=616, name='pick up', time=23.566666666666656)
# TimePoint(taxi_id=798, name='drop off', time=23.566666666666666)
# TimePoint(taxi_id=972, name='pick up', time=23.566666666666666)
# TimePoint(taxi_id=213, name='pick up', time=23.566666666666666)
# TimePoint(taxi_id=802, name='drop off', time=23.56666666666667)
# TimePoint(taxi_id=149, name='end_shift', time=23.56666666666667)
# TimePoint(taxi_id=752, name='pick up', time=23.56666666666667)
# TimePoint(taxi_id=245, name='drop off', time=23.56666666666667)
# TimePoint(taxi_id=900, name='end_shift', time=23.56666666666667)
# TimePoint(taxi_id=968, name='pick up', time=23.566666666666674)
# TimePoint(taxi_id=143, name='drop off', time=23.566666666666677)
# TimePoint(taxi_id=274, name='end_shift', time=23.566666666666688)
# TimePoint(taxi_id=155, name='drop off', time=23.583333333333332)
# TimePoint(taxi_id=104, name='pick up', time=23.583333333333336)
# TimePoint(taxi_id=967, name='drop off', time=23.58333333333334)
# TimePoint(taxi_id=634, name='drop off', time=23.58333333333334)
# TimePoint(taxi_id=370, name='end_shift', time=23.583333333333343)
# TimePoint(taxi_id=221, name='pick up', time=23.599999999999994)
# TimePoint(taxi_id=272, name='end_shift', time=23.599999999999994)
# TimePoint(taxi_id=198, name='drop off', time=23.599999999999998)
# TimePoint(taxi_id=798, name='pick up', time=23.6)
# TimePoint(taxi_id=143, name='pick up', time=23.600000000000012)
# TimePoint(taxi_id=650, name='drop off', time=23.616666666666664)
# TimePoint(taxi_id=155, name='pick up', time=23.616666666666667)
# TimePoint(taxi_id=346, name='drop off', time=23.616666666666667)
# TimePoint(taxi_id=521, name='drop off', time=23.616666666666667)
# TimePoint(taxi_id=802, name='pick up', time=23.61666666666667)
# TimePoint(taxi_id=438, name='drop off', time=23.616666666666674)
# TimePoint(taxi_id=789, name='drop off', time=23.633333333333333)
# TimePoint(taxi_id=564, name='end_shift', time=23.633333333333333)
# TimePoint(taxi_id=383, name='pick up', time=23.633333333333333)
# TimePoint(taxi_id=400, name='drop off', time=23.633333333333333)
# TimePoint(taxi_id=400, name='pick up', time=23.633333333333333)
# TimePoint(taxi_id=572, name='end_shift', time=23.633333333333333)
# TimePoint(taxi_id=689, name='end_shift', time=23.633333333333336)
# TimePoint(taxi_id=288, name='drop off', time=23.63333333333334)
# TimePoint(taxi_id=142, name='drop off', time=23.63333333333334)
# TimePoint(taxi_id=604, name='drop off', time=23.649999999999995)
# TimePoint(taxi_id=487, name='end_shift', time=23.649999999999995)
# TimePoint(taxi_id=778, name='end_shift', time=23.65)
# TimePoint(taxi_id=238, name='drop off', time=23.65)
# TimePoint(taxi_id=993, name='drop off', time=23.65)
# TimePoint(taxi_id=84, name='drop off', time=23.650000000000002)
# TimePoint(taxi_id=608, name='drop off', time=23.650000000000002)
# TimePoint(taxi_id=316, name='end_shift', time=23.650000000000002)
# TimePoint(taxi_id=53, name='end_shift', time=23.650000000000002)
# TimePoint(taxi_id=25, name='drop off', time=23.650000000000002)
# TimePoint(taxi_id=98, name='drop off', time=23.650000000000006)
# TimePoint(taxi_id=967, name='pick up', time=23.650000000000006)
# TimePoint(taxi_id=615, name='drop off', time=23.650000000000006)
# TimePoint(taxi_id=328, name='end_shift', time=23.650000000000006)
# TimePoint(taxi_id=470, name='drop off', time=23.65000000000001)
# TimePoint(taxi_id=271, name='drop off', time=23.666666666666657)
# TimePoint(taxi_id=888, name='drop off', time=23.66666666666666)
# TimePoint(taxi_id=604, name='pick up', time=23.66666666666666)
# TimePoint(taxi_id=650, name='pick up', time=23.666666666666664)
# TimePoint(taxi_id=25, name='pick up', time=23.666666666666668)
# TimePoint(taxi_id=951, name='drop off', time=23.666666666666668)
# TimePoint(taxi_id=444, name='pick up', time=23.66666666666667)
# TimePoint(taxi_id=876, name='drop off', time=23.66666666666667)
# TimePoint(taxi_id=289, name='drop off', time=23.666666666666675)
# TimePoint(taxi_id=142, name='pick up', time=23.666666666666675)
# TimePoint(taxi_id=601, name='drop off', time=23.683333333333326)
# TimePoint(taxi_id=198, name='pick up', time=23.68333333333333)
# TimePoint(taxi_id=399, name='drop off', time=23.683333333333334)
# TimePoint(taxi_id=502, name='drop off', time=23.683333333333334)
# TimePoint(taxi_id=993, name='pick up', time=23.683333333333334)
# TimePoint(taxi_id=520, name='drop off', time=23.683333333333337)
# TimePoint(taxi_id=708, name='drop off', time=23.683333333333337)
# TimePoint(taxi_id=84, name='pick up', time=23.683333333333337)
# TimePoint(taxi_id=776, name='drop off', time=23.683333333333337)
# TimePoint(taxi_id=227, name='end_shift', time=23.68333333333334)
# TimePoint(taxi_id=634, name='pick up', time=23.68333333333334)
# TimePoint(taxi_id=230, name='drop off', time=23.683333333333344)
# TimePoint(taxi_id=346, name='pick up', time=23.7)
# TimePoint(taxi_id=828, name='drop off', time=23.700000000000003)
# TimePoint(taxi_id=245, name='pick up', time=23.700000000000003)
# TimePoint(taxi_id=951, name='pick up', time=23.700000000000003)
# TimePoint(taxi_id=470, name='pick up', time=23.70000000000001)
# TimePoint(taxi_id=21, name='drop off', time=23.70000000000001)
# TimePoint(taxi_id=888, name='pick up', time=23.71666666666666)
# TimePoint(taxi_id=996, name='end_shift', time=23.716666666666665)
# TimePoint(taxi_id=789, name='pick up', time=23.716666666666665)
# TimePoint(taxi_id=7, name='drop off', time=23.71666666666667)
# TimePoint(taxi_id=944, name='pick up', time=23.716666666666672)
# TimePoint(taxi_id=944, name='drop off', time=23.716666666666672)
# TimePoint(taxi_id=289, name='pick up', time=23.716666666666676)
# TimePoint(taxi_id=288, name='end_shift', time=23.716666666666676)
# TimePoint(taxi_id=480, name='drop off', time=23.73333333333333)
# TimePoint(taxi_id=608, name='pick up', time=23.733333333333334)
# TimePoint(taxi_id=216, name='drop off', time=23.733333333333334)
# TimePoint(taxi_id=135, name='drop off', time=23.733333333333338)
# TimePoint(taxi_id=708, name='pick up', time=23.733333333333338)
# TimePoint(taxi_id=615, name='pick up', time=23.733333333333338)
# TimePoint(taxi_id=851, name='drop off', time=23.73333333333334)
# TimePoint(taxi_id=601, name='pick up', time=23.749999999999993)
# TimePoint(taxi_id=651, name='drop off', time=23.749999999999996)
# TimePoint(taxi_id=427, name='drop off', time=23.749999999999996)
# TimePoint(taxi_id=502, name='pick up', time=23.75)
# TimePoint(taxi_id=255, name='drop off', time=23.75)
# TimePoint(taxi_id=876, name='pick up', time=23.750000000000004)
# TimePoint(taxi_id=496, name='drop off', time=23.750000000000007)
# TimePoint(taxi_id=386, name='drop off', time=23.750000000000007)
# TimePoint(taxi_id=438, name='pick up', time=23.750000000000007)
# TimePoint(taxi_id=835, name='drop off', time=23.75000000000001)
# TimePoint(taxi_id=877, name='drop off', time=23.75000000000001)
# TimePoint(taxi_id=209, name='drop off', time=23.76666666666667)
# TimePoint(taxi_id=243, name='drop off', time=23.76666666666667)
# TimePoint(taxi_id=7, name='pick up', time=23.76666666666667)
# TimePoint(taxi_id=98, name='end_shift', time=23.766666666666673)
# TimePoint(taxi_id=230, name='pick up', time=23.766666666666676)
# TimePoint(taxi_id=287, name='drop off', time=23.78333333333333)
# TimePoint(taxi_id=399, name='pick up', time=23.783333333333335)
# TimePoint(taxi_id=804, name='drop off', time=23.783333333333335)
# TimePoint(taxi_id=514, name='drop off', time=23.78333333333334)
# TimePoint(taxi_id=520, name='end_shift', time=23.78333333333334)
# TimePoint(taxi_id=851, name='pick up', time=23.783333333333342)
# TimePoint(taxi_id=414, name='drop off', time=23.783333333333346)
# TimePoint(taxi_id=271, name='end_shift', time=23.79999999999999)
# TimePoint(taxi_id=885, name='drop off', time=23.799999999999997)
# TimePoint(taxi_id=521, name='end_shift', time=23.8)
# TimePoint(taxi_id=464, name='drop off', time=23.800000000000004)
# TimePoint(taxi_id=66, name='drop off', time=23.800000000000008)
# TimePoint(taxi_id=118, name='drop off', time=23.800000000000008)
# TimePoint(taxi_id=386, name='pick up', time=23.800000000000008)
# TimePoint(taxi_id=835, name='pick up', time=23.80000000000001)
# TimePoint(taxi_id=739, name='drop off', time=23.80000000000001)
# TimePoint(taxi_id=480, name='pick up', time=23.816666666666663)
# TimePoint(taxi_id=265, name='drop off', time=23.816666666666666)
# TimePoint(taxi_id=828, name='end_shift', time=23.81666666666667)
# TimePoint(taxi_id=771, name='drop off', time=23.816666666666674)
# TimePoint(taxi_id=21, name='end_shift', time=23.816666666666677)
# TimePoint(taxi_id=997, name='drop off', time=23.81666666666668)
# TimePoint(taxi_id=651, name='pick up', time=23.83333333333333)
# TimePoint(taxi_id=287, name='pick up', time=23.833333333333332)
# TimePoint(taxi_id=238, name='end_shift', time=23.833333333333332)
# TimePoint(taxi_id=209, name='pick up', time=23.833333333333336)
# TimePoint(taxi_id=462, name='drop off', time=23.833333333333336)
# TimePoint(taxi_id=771, name='pick up', time=23.83333333333334)
# TimePoint(taxi_id=814, name='drop off', time=23.83333333333334)
# TimePoint(taxi_id=243, name='pick up', time=23.85)
# TimePoint(taxi_id=1, name='drop off', time=23.85)
# TimePoint(taxi_id=501, name='drop off', time=23.85)
# TimePoint(taxi_id=514, name='pick up', time=23.850000000000005)
# TimePoint(taxi_id=739, name='pick up', time=23.850000000000012)
# TimePoint(taxi_id=794, name='drop off', time=23.866666666666667)
# TimePoint(taxi_id=255, name='end_shift', time=23.866666666666667)
# TimePoint(taxi_id=804, name='pick up', time=23.866666666666667)
# TimePoint(taxi_id=972, name='drop off', time=23.866666666666667)
# TimePoint(taxi_id=668, name='drop off', time=23.86666666666667)
# TimePoint(taxi_id=17, name='drop off', time=23.86666666666667)
# TimePoint(taxi_id=776, name='end_shift', time=23.86666666666667)
# TimePoint(taxi_id=823, name='drop off', time=23.866666666666674)
# TimePoint(taxi_id=877, name='end_shift', time=23.866666666666678)
# TimePoint(taxi_id=997, name='pick up', time=23.86666666666668)
# TimePoint(taxi_id=254, name='drop off', time=23.883333333333336)
# TimePoint(taxi_id=117, name='drop off', time=23.883333333333336)
# TimePoint(taxi_id=118, name='pick up', time=23.88333333333334)
# TimePoint(taxi_id=814, name='pick up', time=23.88333333333334)
# TimePoint(taxi_id=752, name='drop off', time=23.900000000000002)
# TimePoint(taxi_id=216, name='end_shift', time=23.900000000000002)
# TimePoint(taxi_id=496, name='end_shift', time=23.90000000000001)
# TimePoint(taxi_id=427, name='end_shift', time=23.916666666666664)
# TimePoint(taxi_id=919, name='drop off', time=23.916666666666664)
# TimePoint(taxi_id=548, name='drop off', time=23.916666666666668)
# TimePoint(taxi_id=548, name='pick up', time=23.916666666666668)
# TimePoint(taxi_id=462, name='pick up', time=23.916666666666668)
# TimePoint(taxi_id=652, name='drop off', time=23.91666666666667)
# TimePoint(taxi_id=265, name='end_shift', time=23.933333333333334)
# TimePoint(taxi_id=213, name='drop off', time=23.933333333333334)
# TimePoint(taxi_id=501, name='pick up', time=23.933333333333334)
# TimePoint(taxi_id=66, name='pick up', time=23.93333333333334)
# TimePoint(taxi_id=469, name='drop off', time=23.949999999999996)
# TimePoint(taxi_id=819, name='drop off', time=23.949999999999996)
# TimePoint(taxi_id=254, name='pick up', time=23.950000000000003)
# TimePoint(taxi_id=823, name='end_shift', time=23.95000000000001)
# TimePoint(taxi_id=616, name='drop off', time=23.966666666666654)
# TimePoint(taxi_id=919, name='end_shift', time=23.966666666666665)
# TimePoint(taxi_id=633, name='drop off', time=23.966666666666665)
# TimePoint(taxi_id=213, name='pick up', time=23.96666666666667)
# TimePoint(taxi_id=700, name='drop off', time=23.96666666666667)
# TimePoint(taxi_id=550, name='drop off', time=23.96666666666667)
# TimePoint(taxi_id=752, name='pick up', time=23.96666666666667)
# TimePoint(taxi_id=668, name='pick up', time=23.966666666666672)
# TimePoint(taxi_id=652, name='pick up', time=23.966666666666672)
# TimePoint(taxi_id=464, name='end_shift', time=23.966666666666672)
# TimePoint(taxi_id=289, name='drop off', time=23.966666666666676)
# TimePoint(taxi_id=885, name='end_shift', time=23.98333333333333)
# TimePoint(taxi_id=132, name='drop off', time=23.983333333333334)
# TimePoint(taxi_id=135, name='end_shift', time=23.983333333333338)
# TimePoint(taxi_id=221, name='drop off', time=23.999999999999993)
# TimePoint(taxi_id=794, name='pick up', time=24.0)
